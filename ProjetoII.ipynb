# %% [markdown]
# <a href="https://colab.research.google.com/github/deveza88/miscellaneous/blob/main/ProjetoII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ydata_profiling

# %%
import cProfile
import re
import csv
import pandas as pd
from ydata_profiling import ProfileReport

# %%
file_path_sales = 'sales.csv'
df_sales = pd.read_csv(file_path_sales)
df_sales.tail(5)
# Out:
# <ipython-input-7-7fe2cf8f6bb9>:2: DtypeWarning: Columns (11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sales = pd.read_csv(file_path_sales)
#          Unnamed: 0 store_id product_id        date  sales  revenue  stock  \
# 8886053     8886054    S0143      P0676  2019-10-31    NaN      NaN    NaN
# 8886054     8886055    S0143      P0680  2019-10-31    NaN      NaN    NaN
# 8886055     8886056    S0143      P0694  2019-10-31    NaN      NaN    NaN
# 8886056     8886057    S0143      P0718  2019-10-31    NaN      NaN    NaN
# 8886057     8886058    S0143      P0747  2019-10-31    NaN      NaN    NaN
#
#           price promo_type_1 promo_bin_1 promo_type_2 promo_bin_2  \
# 8886053   19.90         PR03     verylow         PR03         NaN
# 8886054  139.90         PR14         NaN         PR03         NaN
# 8886055    7.50         PR14         NaN         PR03         NaN
# 8886056   23.75         PR14         NaN         PR03         NaN
# ...

# %%
file_path_cities = 'cities.csv'
df_cities = pd.read_csv(file_path_cities)
df_cities.head(5)
# Out:
#   store_id storetype_id  store_size city_id_old country_id city_code
# 0    S0036         ST04          21        C001     TURKEY   Denizli
# 1    S0005         ST04          19        C001     TURKEY   Denizli
# 2    S0104         ST04          47        C002     TURKEY    Ankara
# 3    S0068         ST03          14        C003     TURKEY     ?zmir
# 4    S0086         ST03          12        C003     TURKEY     ?zmir

# %%
file_path_revenue= 'forecast_revenue_real_data.csv'
df_revenue = pd.read_csv(file_path_revenue)
df_revenue.tail(5)
# Out:
#       Store        Date  fcst_revenue  WEEk
# 1938  S0143  10/27/2019          93.0    44
# 1939  S0143  10/28/2019          93.0    44
# 1940  S0143  10/29/2019          93.0    44
# 1941  S0143  10/30/2019          92.0    44
# 1942  S0143  10/31/2019          89.0    44

# %%
file_path_product = 'product.csv'
df_product = pd.read_csv(file_path_product)
df_product.head(5)
# Out:
#   product_id  product_length  product_depth  product_width cluster_id  \
# 0      P0000             5.0           20.0           12.0        NaN
# 1      P0001            13.5           22.0           20.0  cluster_5
# 2      P0002            22.0           40.0           22.0  cluster_0
# 3      P0004             2.0           13.0            4.0  cluster_3
# 4      P0005            16.0           30.0           16.0  cluster_9
#
#   hierarchy1_id hierarchy2_id hierarchy3_id hierarchy4_id hierarchy5_id
# 0           H00         H0004       H000401     H00040105   H0004010534
# 1           H01         H0105       H010501     H01050100   H0105010006
# 2           H03         H0315       H031508     H03150800   H0315080028
# 3           H03         H0314       H031405     H03140500   H0314050003
# 4           H03         H0312       H031211     H03121109   H0312110917

# %%
file_path_cities = 'cities.csv'
df_cities = pd.read_csv(file_path_cities)
df_cities.head(5)
# Out:
#   store_id storetype_id  store_size city_id_old country_id city_code
# 0    S0036         ST04          21        C001     TURKEY   Denizli
# 1    S0005         ST04          19        C001     TURKEY   Denizli
# 2    S0104         ST04          47        C002     TURKEY    Ankara
# 3    S0068         ST03          14        C003     TURKEY     ?zmir
# 4    S0086         ST03          12        C003     TURKEY     ?zmir

# %% [markdown]
# Proffiling dos restantes ficheiros csv

# %%
# Gerar o relatório de profiling
csv_files = [
    ('sales.csv', 'Vendas'),
    ('cities.csv', 'Relatório de Profiling - Cities'),
    ('forecast_revenue_real_data.csv', 'Relatório de Profiling - Forecast Revenue Real Data'),
    ('product.csv', 'Relatório de Profiling - Product')
]

for file_path, report_title in csv_files:
    df = pd.read_csv(file_path)

    profile = ProfileReport(df, title=report_title, explorative=True)

    output_file = file_path.replace('.csv', '_profiling_report.html')
    profile.to_file(output_file)

    print(f"Relatório de profiling gerado e salvo como '{output_file}'")
# Out:
# <ipython-input-19-8ab386e2adb2>:10: DtypeWarning: Columns (11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Relatório de profiling gerado e salvo como 'sales_profiling_report.html'
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Relatório de profiling gerado e salvo como 'cities_profiling_report.html'
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
# ...

# %%
#Data ETL
from datetime import date
df_sales['store_id'] = df_sales['store_id'].astype(str)
df_sales['product_id'] = df_sales['product_id'].astype(str)
df_sales['date'] = pd.to_datetime(df_sales['date'], format='%Y-%m-%d')
# Format the 'date' column to 'YYYY-M-D'
df_sales['sales'] = df_sales['sales'].astype(float)
df_sales['revenue'] = df_sales['revenue'].astype(float)
df_sales['stock'] = df_sales['stock'].astype(float)
df_sales['promo_type_1'] = df_sales['promo_type_1'].astype(str)
df_sales['promo_bin_1'] = df_sales['promo_bin_1'].astype(str)
df_sales['promo_type_1'] = df_sales['promo_type_1'].astype(str)
df_sales['promo_type_2'] = df_sales['promo_type_2'].astype(str)
df_sales['promo_bin_2'] = df_sales['promo_bin_2'].astype(str)
df_sales['promo_discount_2'] = df_sales['promo_discount_2'].astype(str)
df_sales['promo_discount_type_2'] = df_sales['promo_discount_type_2'].astype(str)

df_cities['store_id'] = df_cities['store_id'].astype(str)
df_cities['storetype_id'] = df_cities['storetype_id'].astype(str)
df_cities['store_size'] = df_cities['store_size'].astype(str)
df_cities['city_id_old'] = df_cities['city_id_old'].astype(str)
df_cities['country_id'] = df_cities['country_id'].astype(str)
df_cities['city_code'] = df_cities['city_code'].astype(str)

df_revenue['Store'] = df_revenue['Store'].astype(str)
# Convert the 'date' column to datetime
df_revenue['Date'] = pd.to_datetime(df_revenue['Date'], format='%m/%d/%Y')
# Format the 'date' column to 'YYYY-M-D'
df_revenue['Date'] = df_revenue['Date'].dt.strftime('%Y-%-m-%-d')
df_revenue['fcst_revenue'] = df_revenue['fcst_revenue'].astype(float)
df_revenue['WEEk'] = df_revenue['WEEk'].astype(str)

df_product['product_id'] = df_product['product_id'].astype(str)
df_product['product_length'] = df_product['product_length'].astype(float)
df_product['product_depth'] = df_product['product_depth'].astype(float)
df_product['product_width'] = df_product['product_width'].astype(float)
df_product['cluster_id'] = df_product['cluster_id'].astype(str)
df_product['hierarchy1_id'] = df_product['hierarchy1_id'].astype(str)
df_product['hierarchy2_id'] = df_product['hierarchy2_id'].astype(str)
df_product['hierarchy3_id'] = df_product['hierarchy3_id'].astype(str)
df_product['hierarchy4_id'] = df_product['hierarchy4_id'].astype(str)
df_product['hierarchy5_id'] = df_product['hierarchy5_id'].astype(str)


df_cities['store_id']= df_cities['store_id'].astype(str)
df_cities['storetype_id']= df_cities['storetype_id'].astype(str)
df_cities['store_size']= df_cities['store_size'].astype(int)
df_cities['city_id_old']= df_cities['city_id_old'].astype(str)
df_cities['country_id']= df_cities['country_id'].astype(str)
df_cities['city_code']= df_cities['city_code'].astype(str)

# %%
df_revenue.tail(5)
#df_sales.tail(5)
# Out:
#       Store        Date  fcst_revenue WEEk
# 1938  S0143  2019-10-27          93.0   44
# 1939  S0143  2019-10-28          93.0   44
# 1940  S0143  2019-10-29          93.0   44
# 1941  S0143  2019-10-30          92.0   44
# 1942  S0143  2019-10-31          89.0   44

# %%
#df_sales['promo_discount_2'].replace('nan', 0, inplace=True)
#print(df.head(10))
# Out:
#       Store        Date  fcst_revenue  WEEk
# 1938  S0143  10/27/2019          93.0    44
# 1939  S0143  10/28/2019          93.0    44
# 1940  S0143  10/29/2019          93.0    44
# 1941  S0143  10/30/2019          92.0    44
# 1942  S0143  10/31/2019          89.0    44

# %%
#Split Data Sales 1 week before
df_sales_1 = df_sales[df_sales['date'] < '2019-10-24']
df_sales_1.tail(5)
# Out:
#          Unnamed: 0 store_id product_id       date  sales  revenue  stock  \
# 8885509     8885510    S0143      P0676 2019-10-23    NaN      NaN    NaN
# 8885510     8885511    S0143      P0680 2019-10-23    NaN      NaN    NaN
# 8885511     8885512    S0143      P0694 2019-10-23    NaN      NaN    NaN
# 8885512     8885513    S0143      P0718 2019-10-23    NaN      NaN    NaN
# 8885513     8885514    S0143      P0747 2019-10-23    NaN      NaN    NaN
#
#           price promo_type_1 promo_bin_1 promo_type_2 promo_bin_2  \
# 8885509   19.90         PR14         nan         PR03         nan
# 8885510  139.90         PR10     verylow         PR03         nan
# 8885511    7.50         PR06    veryhigh         PR03         nan
# 8885512   23.75         PR14         nan         PR03         nan
# 8885513   21.90         PR14         nan         PR03         nan
#
#         promo_discount_2 promo_discount_type_2
# 8885509              nan                   nan
# ...
